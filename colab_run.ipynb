# %% [markdown]
# # 🧠 DikaAi - Google Colab
#
# Copy-paste `colab_simple.py` ke cell di bawah, ganti config, lalu Run!
#
# [📄 Lihat colab_simple.py](https://github.com/dikaofc/dikaai/blob/main/colab_simple.py)

# %%
#@title 🚀 Run DikaAi (paste semua dari colab_simple.py, ganti config lalu Run)

#@markdown ### Ganti config ini:
API_ID = '12345678' #@param {type:"string"}
API_HASH = 'abc123def456' #@param {type:"string"}
PHONE = '+6281234567890' #@param {type:"string"}

#@markdown ---
#@markdown **Atau paste isi `colab_simple.py` di bawah ini:**

# Quick setup tanpa copy-paste manual
# !pip install telethon aiohttp -q
# !git clone https://github.com/dikaofc/dikaai.git /content/dikaai
# %cd /content/dikaai

import os
os.environ['TELEGRAM_API_ID'] = API_ID
os.environ['TELEGRAM_API_HASH'] = API_HASH
os.environ['TELEGRAM_PHONE'] = PHONE

with open('config.env', 'w') as f:
    f.write(f'TELEGRAM_API_ID={API_ID}\nTELEGRAM_API_HASH={API_HASH}\nTELEGRAM_PHONE={PHONE}\n')

# !python main.py
