# %% [markdown]
# # 🧠 DikaAi - Google Colab
#
# Isi config di bawah, lalu Run!
#
# **Dashboard Vercel:** https://dikaai.vercel.app

# %%
#@title 🚀 Run DikaAi - Isi Config Lalu Run!

#@markdown ### Telegram (wajib) - dari https://my.telegram.org
API_ID = '12345678' #@param {type:"string"}
API_HASH = 'abc123def456' #@param {type:"string"}
PHONE = '+6281234567890' #@param {type:"string"}

#@markdown ### Upstash Redis (wajib biar dashboard Vercel jalan)
#@markdown Daftar gratis: https://upstash.com → Create Database → Copy URL + Token
REDIS_URL = 'https://xxx.upstash.io' #@param {type:"string"}
REDIS_TOKEN = 'AXxx...' #@param {type:"string"}

#@markdown ---

# Install + Clone
# !pip install telethon aiohttp -q
# !git clone https://github.com/dikaofc/dikaai.git /content/dikaai
# %cd /content/dikaai

# Save config
import os
with open('config.env', 'w') as f:
    f.write(f'TELEGRAM_API_ID={API_ID}\n')
    f.write(f'TELEGRAM_API_HASH={API_HASH}\n')
    f.write(f'TELEGRAM_PHONE={PHONE}\n')
    f.write(f'UPSTASH_REDIS_REST_URL={REDIS_URL}\n')
    f.write(f'UPSTASH_REDIS_REST_TOKEN={REDIS_TOKEN}\n')

print('✅ Config saved!')
print(f'📱 Telegram: {PHONE}')
print(f'🔴 Redis: {REDIS_URL[:30]}...')
print(f'📊 Dashboard: https://dikaai.vercel.app')

# Run!
# !python main.py
