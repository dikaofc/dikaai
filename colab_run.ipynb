# %% [markdown]
# # 🧠 DikaAi - Google Colab Setup
# **Paling Ringan Sedunia 🚀**
#
# Jalankan semua cell dari atas ke bawah.
#
# **Step 1:** Jalankan cell setup (clone + install)
#
# **Step 2:** Isi API credentials Telegram
#
# **Step 3:** Run DikaAi!

# %%
#@title 1️⃣ Setup: Clone Repo + Install Dependencies
# !git clone https://github.com/dikaofc/dikaai.git
# %cd dikaai
# !pip install telethon aiohttp -q
print('✅ Setup complete!')

# %%
#@title 2️⃣ Setup: Isi Telegram API Credentials
# Dapat dari https://my.telegram.org

import os

#@markdown ### Isi data kamu di bawah ini:
API_ID = '12345678' #@param {type:"string"}
API_HASH = 'abc123def456' #@param {type:"string"}
PHONE = '+6281234567890' #@param {type:"string"}

os.environ['TELEGRAM_API_ID'] = API_ID
os.environ['TELEGRAM_API_HASH'] = API_HASH
os.environ['TELEGRAM_PHONE'] = PHONE

print('✅ Credentials saved!')
print(f'   API_ID: {API_ID[:4]}...')
print(f'   PHONE: {PHONE[:6]}...')

# %%
#@title 3️⃣ Run DikaAi! (Web Scrape + Training + Bot)
#@markdown Ini akan:
#@markdown - 🌐 Scrape web (Wikipedia, StackOverflow, GitHub)
#@markdown - 📖 Build vocabulary dari semua data
#@markdown - 🧠 Training model otomatis
#@markdown - 📱 Connect Telegram + auto-reply
#@markdown - 🔄 Re-scrape tiap 6 jam

# !python main.py

# %% [markdown]
# ---
# ## 📋 Tips
#
# - **Colab timeout**: Kalau Colab disconnect, jalankan ulang dari cell 3
# - **Telegram login**: Akan minta kode verifikasi, cek HP kamu
# - **Dashboard**: Buka `http://localhost:8888` di browser Colab
# - **Stop**: Tekan tombol stop atau `Ctrl+C`
